# %%
import pandas as pd
import yfinance as yf
import datetime

import os
from dotenv import load_dotenv
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine, text

# %%
load_dotenv()

DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_NAME = os.getenv("DB_NAME")

# %%
b3_tickers = [
    "PETR4.SA",
    "PETR3.SA",
    "VALE3.SA",
    "ITUB4.SA",
    "ITUB3.SA",
    "BBDC4.SA",
    "BBDC3.SA",
    "BBAS3.SA",
    "ABEV3.SA",
    "WEGE3.SA",
    "MGLU3.SA",
    "RENT3.SA",
    "LREN3.SA",
    "ELET3.SA",
    "ELET6.SA",
    "B3SA3.SA",
    "SUZB3.SA",
    "RAIL3.SA",
    "GGBR4.SA",
    "CSNA3.SA",
    "USIM5.SA",
    "JBSS3.SA",
    "BRFS3.SA",
    "MRVE3.SA",
    "CYRE3.SA",
    "HAPV3.SA",
    "RADL3.SA",
    "EQTL3.SA",
    "CMIG4.SA",
    "CPLE6.SA",
    "TAEE11.SA",
    "KLBN11.SA",
    "VIVT3.SA",
    "TIMS3.SA",
    "COGN3.SA",
    "YDUQ3.SA",
    "PRIO3.SA",
    "BRKM5.SA",
    "EMBR3.SA",
    "ASAI3.SA",
    "CRFB3.SA",
    "PCAR3.SA",
    "MULT3.SA",
    "IGTI11.SA",
    "ALOS3.SA",
    "ENEV3.SA",
    "ENGI11.SA",
    "SBSP3.SA",
    "SANB11.SA",
    "BPAC11.SA"
]

# %%
us_tickers = [
    "AAPL",
    "MSFT",
    "GOOGL",
    "GOOG",
    "AMZN",
    "NVDA",
    "META",
    "TSLA",
    "NFLX",
    "AMD",
    "INTC",
    "ORCL",
    "IBM",
    "ADBE",
    "CRM",
    "PYPL",
    "UBER",
    "ABNB",
    "SHOP",
    "PLTR",
    "JPM",
    "BAC",
    "WFC",
    "GS",
    "MS",
    "V",
    "MA",
    "AXP",
    "DIS",
    "KO",
    "PEP",
    "MCD",
    "WMT",
    "COST",
    "TGT",
    "NKE",
    "SBUX",
    "PFE",
    "JNJ",
    "MRK",
    "UNH",
    "LLY",
    "XOM",
    "CVX",
    "BA",
    "CAT",
    "GE",
    "F",
    "GM"
]

# %%
etf_tickers = [
    "SPY",
    "VOO",
    "IVV",
    "QQQ",
    "DIA",
    "IWM",
    "VTI",
    "VEA",
    "VWO",
    "EFA",
    "EEM",
    "XLK",
    "XLF",
    "XLE",
    "XLV",
    "XLY",
    "XLP",
    "XLI",
    "XLB",
    "XLU",
    "VNQ",
    "ARKK",
    "BOVA11.SA",
    "IVVB11.SA",
    "SMAL11.SA",
    "HASH11.SA",
    "XFIX11.SA"
]

# %%
crypto_tickers = [
    "BTC-USD",
    "ETH-USD",
    "BNB-USD",
    "SOL-USD",
    "XRP-USD",
    "ADA-USD",
    "DOGE-USD",
    "AVAX-USD",
    "DOT-USD",
    "LINK-USD",
    "MATIC-USD",
    "LTC-USD",
    "BCH-USD",
    "UNI-USD",
    "ATOM-USD"
]

# %%
tickers = b3_tickers + us_tickers + etf_tickers + crypto_tickers

# %%
data_list = []
dados = pd.DataFrame()
for ticker in tickers:
    try:
        df = yf.Ticker(ticker).history(period="1d", interval="1h") 

        if df.empty:
            print("Sem dados")
            continue;

        df["Ticker"] = ticker
        df.reset_index(inplace=True)
        df.columns = [col.lower() for col in df.columns]
        data_list.append(df)
        
    except Exception as e:
        print(e)
        continue;
 
if not data_list:
    pd.DataFrame()
else:
    dados = pd.concat(data_list)
# Out:
# $ELET3.SA: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# Sem dados
# $ELET6.SA: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# Sem dados
# $JBSS3.SA: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# Sem dados
# $BRFS3.SA: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# Sem dados
# $CPLE6.SA: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# Sem dados
# $EMBR3.SA: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# Sem dados
# $CRFB3.SA: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# Sem dados
# $MATIC-USD: possibly delisted; no price data found  (period=1d)
# ...

# %%
dados = dados.rename(columns={"stock splits": "stock_splits", "capital gains": "capital_gains"})

# %%
dados.dtypes
# Out:
# datetime          object
# open             float64
# high             float64
# low              float64
# close            float64
# volume             int64
# dividends        float64
# stock_splits     float64
# ticker               str
# capital_gains    float64
# dtype: object

# %%
len(dados)
# Out:
# 314

# %%
from sqlalchemy import create_engine, text

# Formato da URL: dialeto://usuario:senha@host:porta/banco
engine = create_engine(f"postgresql://{DB_USER}:{DB_PASSWORD}@localhost:5432/{DB_NAME}")

# %%
ddl = """

    CREATE TABLE IF NOT EXISTS stock_quotes (
        datetime TIMESTAMPTZ, 
        open FLOAT(53), 
        high FLOAT(53), 
        low FLOAT(53), 
        close FLOAT(53), 
        volume BIGINT, 
        dividends FLOAT(53), 
        stock_splits FLOAT(53),
        ticker VARCHAR,
        capital_gains FLOAT(53),
        PRIMARY KEY (ticker, datetime)

);

"""

# %%
with engine.begin() as conn:
    conn.execute(text(ddl))

# %%
def postgres_upsert(table, conn, keys, data_iter):
    data = [dict(zip(keys, row)) for row in data_iter]
    
    # Monta a query INSERT ... ON CONFLICT
    # Exemplo: ATUALIZAR nome SE email CONFLITAR
    sql = f"""
        INSERT INTO {table.table.name} ({', '.join(keys)})
        VALUES ({', '.join([f":{k}" for k in keys])})
        ON CONFLICT (ticker, datetime)
        DO UPDATE SET
            open = EXCLUDED.open,
            high = EXCLUDED.high,
            low = EXCLUDED.low,
            close = EXCLUDED.close,
            volume = EXCLUDED.volume,
            dividends = EXCLUDED.dividends,
            stock_splits = EXCLUDED.stock_splits,
            capital_gains = EXCLUDED.capital_gains
    """
    conn.execute(text(sql), data)

# %%
dados.to_sql('stock_quotes', engine, if_exists='append', index=False, method=postgres_upsert)
